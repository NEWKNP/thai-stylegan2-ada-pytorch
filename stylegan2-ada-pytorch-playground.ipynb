# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/rv_project/StyleGAN/pretrain01/study
# Out:
# /content/drive/.shortcut-targets-by-id/11NKrSNTTLwWzKUdAP3frKkQ1EDNbrZJ_/rv_project/StyleGAN/pretrain01/study

# %%
# !git clone https://NEWKNP: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@github.com/NEWKNP/thai-stylegan2-ada-pytorch
# Out:
# Cloning into 'thai-stylegan2-ada-pytorch'...
# ...

# %%
# %cd thai-stylegan2-ada-pytorch
# Out:
# /content/drive/.shortcut-targets-by-id/11NKrSNTTLwWzKUdAP3frKkQ1EDNbrZJ_/rv_project/StyleGAN/pretrain01/study/thai-stylegan2-ada-pytorch

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add .

# %%
! git commit -m "CLONE stylegan2-ada pytorch from NVIDIA"
# Out:
# [master 262131f] CLONE stylegan2-ada pytorch from NVIDIA
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite stylegan2-ada-pytorch-playground.ipynb (82%)

# %%
# !git remote add origin https://github.com/NEWKNP/thai-stylegan2-ada-pytorch.git
# Out:
# fatal: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://github.com/NEWKNP/thai-stylegan2-ada-pytorch.git (fetch)
# origin	https://github.com/NEWKNP/thai-stylegan2-ada-pytorch.git (push)

# %%
# !git config --global user.email '59090021@kmitl.ac.th'
# !git config --global user.name 'NEWKNP'

# %%
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
